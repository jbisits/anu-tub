# %% [markdown]
# # One degree zstar model
#
# This notebook looks at the one degree zstar run of ANU-TUB.
# I tried to initialise the model with output from the 0.25 degree version that I interpolated onto the one degree grid but this did not work because of the thickness which caused errors in the SSH.
# I am not sure if this was due to remapping to zstar, I used HYCOM model output to generate the initial salinity, or if it was related to the interpolation not conserving things properly.
# This may be able to be further explored but for now I have a one year run from an at rest state.
# The restart files from Andy and Angus' previous runs were from 500 years.
# This one year run took ~55mins and used 75SUs.
# Suppposing a single year varies between 75 and 100SUs, need between 37-50KSUs to get to 500 years.
#
# Will think about what best way to go is.

# %%
zstar_one_degree_output = "/g/data/e14/jb2381/one-degree-anu-tub/output/zstar"
if pwd() != zstar_one_degree_output
    cd(zstar_one_degree_output)
end

using Pkg
Pkg.activate("..")
using NCDatasets, CairoMakie, NaNStatistics, Dates
# Out:
#   Activating project at `/g/data/e14/jb2381/one-degree-anu-tub/output`

# %% [markdown]
# ## Initial conditions
#
# These are generated and saved; just want to see what they were.

# %%
initial_month = "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output000"
ics = joinpath(initial_month, "MOM_IC.nc")
# Out:
# "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output000/MOM_IC.nc"

# %%
ds = NCDataset(ics, maskingvalue = NaN)
xh = ds["lonh"][:]
yh = ds["lath"][:]
zl = ds["Layer"][:]
θᵢ = ds["Temp"][:, :, :, 1]
initial_time = ds["Time"][:]
close(ds)
# Out:
# closed Dataset

# %%
initial_time
# Out:
# 1-element Vector{Float64}:
#  0.0

# %%
colormap = :thermal
colorrange  = (-2, 30)

fig = Figure(size = (800, 500))

ax = Axis(fig[1, 1], xlabel = "xh", ylabel = "yh", title = "Initial SST")
heatmap!(ax, xh, yh, θᵢ[:, :, 1]; colormap, colorrange)

ax2 = Axis(fig[1, 2], xlabel = "yh", ylabel = "zl", title = "Initial Zonal slice")
hm = heatmap!(ax2, yh, -zl, θᵢ[20, :, :]; colormap, colorrange)

Colorbar(fig[1, 3], hm, label = "θ (°C)")
fig

# %% [markdown]
# ## First year of output
#
# This is the first month of output from the initial conditions above.

# %%
monthly = joinpath(initial_month, "ocean_month.nc")
zmonthly = joinpath(initial_month, "ocean_month_z.nc")
# Out:
# "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output000/ocean_month_z.nc"

# %%
ds = NCDataset(monthly, maskingvalue = NaN)
h_fm = ds["thkcello"][:, :, :, :]
θ_fm = ds["thetao"][:, :, :, :]
close(ds)

∫h = cumsum(h, dims = 3)

ds = NCDataset(zmonthly, maskingvalue = NaN)
σ₂ = ds["rhopot2"][:, :, :, :]
xh = ds["xh"][:]
yh = ds["yh"][:]
zl = ds["z_l"][:]
fm_time = ds["time"][:]
close(ds)
# Out:
# closed Dataset

# %%
lon = 20
t = 12

fig = Figure(size = (700, 500))

colormap = :dense
colorrange = (1028, 1038)
depth_levels = 1:75

axtop = Axis(fig[1, 1], xlabel = "Latitude (°N)", ylabel = "z (m)", title = "zstar")
hidexdecorations!(axtop, ticks = false)
hm = heatmap!(axtop, yh, -zl, σ₂[lon, :, :, t]; colorrange, colormap)
for i ∈ depth_levels
    lines!(axtop, yh, -∫h[lon, :, i, t], color = :white, linewidth = 0.3)
end
ylims!(axtop, -500, 0)
axbot = Axis(fig[2, 1], xlabel = "Latitude (°N)", ylabel = "z (m)")
hm = heatmap!(axbot, yh, -zl, σ₂[lon, :, :, t]; colorrange, colormap)
for i ∈ depth_levels
    lines!(axbot, yh, -∫h[lon, :, i, t], color = :white, linewidth = 0.3)
end
ylims!(axbot, -4000, -500)
axbot.yticks = [-4000, -3000, -2000, -1000, -500]

Colorbar(fig[:, 2], hm, label = "σ₂ (kgm⁻³)")

fig

# %% [markdown]
# ## Compare ics to first saved snapshot
#
# Here it looks like the first saved snapshot is the temperature of the first month.
# This means that from initial conditions, the output `advection_xy` and all the processes that contribute to changing temperature from T0 (ic) -> T1 (saved_output) should be accessed with index 1 and the difference is between the 1 and the initial condition.
# So `thetao[:, :, :, n]` is the updated temperature value from `advection_xy[:, :, :, n]` etc. Meaning the change in $hc^{2}$ between tn-1 and tn will be driven by processes with index n.
#
# Maybe this was different from some of the earlier data that Jan gave me from OM4 as the initial condition saving can be handled differently.
# I guess with Payu they save the initial values to `MOM_IC.nc` then the first saved snapshot `ocean_month.nc`.
# This configuration would be better for restarts so that things are not saved twice but I should check this.

# %%
colormap = :thermal
colorrange  = (-2, 30)

fig = Figure(size = (800, 500))

ax = Axis(fig[1, 1], xlabel = "xh", ylabel = "yh", title = "Initial SST")
heatmap!(ax, xh, yh, θᵢ[:, :, 1]; colormap, colorrange)

ax2 = Axis(fig[1, 2], xlabel = "yh", ylabel = "zl", title = "Initial Zonal slice")
hm = heatmap!(ax2, yh, -zl, θᵢ[20, :, :]; colormap, colorrange)

ax3 = Axis(fig[2, 1], xlabel = "xh", ylabel = "yh", title = "Initial SST")
heatmap!(ax3, xh, yh, θ_fm[:, :, 1, 1]; colormap, colorrange)

ax4 = Axis(fig[2, 2], xlabel = "yh", ylabel = "zl", title = "Initial Zonal slice")
hm = heatmap!(ax4, yh, -zl, θ_fm[20, :, :, 1]; colormap, colorrange)

Colorbar(fig[:, 3], hm, label = "θ (°C)")
fig

# %% [markdown]
# ## Second year of snapshot

# %%
first_restart = "/g/data/e14/jb2381/one-degree-anu-tub/restarts/zstar/restart000/MOM.res.nc"

ds = NCDataset(first_restart, maskingvalue = NaN)
h_restart = ds["h"][:, :, :, 1]
θ_restart = ds["Temp"][:, :, :, 1]
close(ds)

seoncd_month = "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output001"
smonthly = joinpath(seoncd_month, "ocean_month.nc")
szmonthly = joinpath(seoncd_month, "ocean_month_z.nc")

ds = NCDataset(smonthly, maskingvalue = NaN)
sh = ds["thkcello"][:, :, :, :]
sθ_fm = ds["thetao"][:, :, :, :]
close(ds)

∫h = cumsum(h, dims = 3)

ds = NCDataset(szmonthly, maskingvalue = NaN)
σ₂ = ds["rhopot2"][:, :, :, :]
xh = ds["xh"][:]
yh = ds["yh"][:]
zl = ds["z_l"][:]
fm_time = ds["time"][:]
close(ds)
# Out:
# closed Dataset

# %%
colormap = :thermal
colorrange  = (-2, 30)

fig = Figure(size = (800, 500))

ax = Axis(fig[1, 1], xlabel = "xh", ylabel = "yh", title = "Restart SST")
heatmap!(ax, xh, yh, θ_restart[:, :, 1]; colormap, colorrange)

ax2 = Axis(fig[1, 2], xlabel = "yh", ylabel = "zl", title = "Restart Zonal slice")
hm = heatmap!(ax2, yh, -zl, θ_restart[20, :, :]; colormap, colorrange)

ax3 = Axis(fig[2, 1], xlabel = "xh", ylabel = "yh", title = "First saved SST")
heatmap!(ax3, xh, yh, sθ_fm[:, :, 1, 1]; colormap, colorrange)

ax4 = Axis(fig[2, 2], xlabel = "yh", ylabel = "zl", title = "First saved Zonal slice")
hm = heatmap!(ax4, yh, -zl, sθ_fm[20, :, :, 1]; colormap, colorrange)
Colorbar(fig[1:2, 3], hm, label = "θ (°C)")

ax5 = Axis(fig[3, 1], xlabel = "xh", ylabel = "yh", title = "Difference")
heatmap!(ax5, xh, yh, θ_restart[:, :, 1] .- sθ_fm[:, :, 1, 1]; colormap = :balance, colorrange=(-1e-1,1e-1))

ax6 = Axis(fig[3, 2], xlabel = "yh", ylabel = "zl", title = "Difference")
hm = heatmap!(ax6, yh, -zl, θ_restart[20, :, :] .- sθ_fm[20, :, :, 1]; colormap = :balance, colorrange=(-1e-1,1e-1))
Colorbar(fig[3, 3], hm, label = "θ (°C)")
fig

# %%
θ_fm[:, :, :, :] .*= h_fm[:, :, :, :] # temperature content at end of first lot of saved output
θ_restart[:, :, :, 1] .*= h_restart[:, :, :, 1] # temperature content in first restart file
sθ_fm[:, :, :, :] .*= sh[:, :, :, :] # temperature content at first saved snapshot of second ouput
find_nan = .!isnan.(θ_fm[:, :, :, end])
θ_fm[:, :, :, end] .*= find_nan
sθ_fm[:, :, :, 1] .*= find_nan
θ_restart[:, :, :, 1] .*= find_nan
sum(θ_fm[:, :, :, end]), sum(θ_restart), sum(sθ_fm[:, :, :, 1])
# Out:
# (1.5994735554456145e8, 1.599045207416171e8, 1.5986164370825055e8)

# %% [markdown]
# # Variance production
#
# From this one year run, the numerical mixing is not likely to be that revealing.
# Currently this is more a check because I am using the [ACCESS-NRI build](https://github.com/ACCESS-NRI/ACCESS-OM3/pull/233) of my [MOM6 PR](https://github.com/ACCESS-NRI/MOM6/pull/57).

# %%
ds = NCDataset(monthly, maskingvalue = NaN)
asvp = nanmean(ds["T_advection_scheme_variance_production"][:, :, :, :], dim = 4)
h_depth = nanmean(ds["thkcello"][:, :, :, :], dim = 4)
h_depth = nansum(h_depth, dim = 3)
h_zonal = nanmean(ds["thkcello"][:, :, :, :], dim = 4)
h_zonal = nansum(h_zonal, dim = 1)
close(ds)

slope = .!isnan.(σ₂[20, :, :, 1])

asvp_zonal = nansum(asvp, dim = 1)
asvp_zonal ./= h_zonal
asvp_zonal .*= slope
replace!(asvp, 0 => NaN)

asvp_depth = nansum(asvp, dim = 3)
asvp_depth ./= h_depth
nothing

# %%
fig = Figure(size = (1000, 500))

colormap = :balance
colorrange = (-1e-8, 1e-8)

axtop = Axis(fig[1, 1], xlabel = "Latitude (°N)", ylabel = "z (m)", title = "zstar")
hidexdecorations!(axtop, ticks = false)
hm = heatmap!(axtop, yh, -zl, asvp_zonal; colorrange, colormap)
ylims!(axtop, -500, 0)
axbot = Axis(fig[2, 1], xlabel = "Latitude (°N)", ylabel = "z (m)")
hm = heatmap!(axbot, yh, -zl, asvp_zonal; colorrange, colormap)
ylims!(axbot, -4000, -500)
axbot.yticks = [-4000, -3000, -2000, -1000, -500]

ax = Axis(fig[:, 2], xlabel = "Longitude", ylabel = "Latitude")
heatmap!(ax, xh, yh, asvp_depth; colormap, colorrange)

Colorbar(fig[:, 3], hm, label = "Variance production (°C²s⁻¹)")

fig

# %% [markdown]
# ## Later years
#
# The first extended run was for ten years.
# Just checking what the temperature looks like.
# Subsequent runs are all ten years long.

# %%
later = "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output050"
monthly = joinpath(later, "ocean_month.nc")
zmonthly = joinpath(later, "ocean_month_z.nc")
# Out:
# "/g/data/e14/jb2381/one-degree-anu-tub/control/zstar/archive/output050/ocean_month_z.nc"

# %%
ds = NCDataset(zmonthly, maskingvalue = NaN)
t = round.(ds["time"][:], Hour)
xh = ds["xh"][:]
yh = ds["yh"][:]
zl = ds["z_l"][:]
θ = ds["thetao"][:, :, :, :] # last snapshot
close(ds)

t_index = 120
zonal_θ = θ[20, :, :, t_index]
sst_θ = θ[:, :, 1, t_index]

colormap = :thermal
colorrange  = (-2, 30)

fig = Figure(size = (800, 500))

ax = Axis(fig[1, 1], xlabel = "xh", ylabel = "yh", title = "SST - $(t[t_index])")
heatmap!(ax, xh, yh, sst_θ; colormap, colorrange)

ax2 = Axis(fig[1, 2], xlabel = "yh", ylabel = "zl", title = "Zonal slice - $(t[t_index])")
hm = heatmap!(ax2, yh, -zl, zonal_θ; colormap, colorrange)

Colorbar(fig[1, 3], hm, label = "θ (°C)")
fig

# %% [markdown]
# All looks to be doing the right thing.
# At this stage just need to run it out; aiming for 500 years.

# %%
ds = NCDataset(monthly, maskingvalue = NaN)
asvp = ds["T_advection_scheme_variance_production"][:, :, :, :]
h = ds["thkcello"][:, :, :, :]
close(ds)

∫h_vc = nanmean(h, dim = (1, 4))
∫h_vc = cumsum(∫h_vc, dims = 2)

slope = .!isnan.(θ[20, :, :, 1])

asvp_zonal = nansum(asvp, dim = 1)
asvp_zonal ./= nansum(h, dim = 1)
asvp_zonal = nanmean(asvp_zonal, dim = 3)
asvp_zonal .*= slope
replace!(asvp_zonal, 0 => NaN)

asvp_depth = nansum(asvp, dim = 3)
asvp_depth ./= nansum(h, dim = 3)
asvp_depth = nanmean(asvp_depth, dim = 3)
nothing

# %%
fig = Figure(size = (1000, 500))

colormap = :balance
colorrange = (-1e-6, 1e-6)

axtop = Axis(fig[1, 1], xlabel = "Latitude (°N)", ylabel = "z (m)", title = "zstar")
hidexdecorations!(axtop, ticks = false)
hm = surface!(axtop, yh, -∫h_vc, zeros(size(asvp_zonal)); colorrange, colormap, color = asvp_zonal, shading = NoShading)
xlims!(axtop, -70, 70)
ylims!(axtop, -500, 0)
axbot = Axis(fig[2, 1], xlabel = "Latitude (°N)", ylabel = "z (m)")
hm = surface!(axbot, yh, -∫h_vc, zeros(size(asvp_zonal)); colorrange, colormap, color = asvp_zonal, shading = NoShading)
xlims!(axbot, -70, 70)
ylims!(axbot, -4000, -500)
axbot.yticks = [-4000, -3000, -2000, -1000, -500]

ax = Axis(fig[:, 2], xlabel = "Longitude", ylabel = "Latitude")
heatmap!(ax, xh, yh, asvp_depth; colormap, colorrange)

Colorbar(fig[:, 3], hm, label = "Variance production (°C²s⁻¹)")

fig
